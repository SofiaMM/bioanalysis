# %%
import datetime
import mysql.connector
import operator
import numpy as np
from scipy import special

import matplotlib as mlp
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import matplotlib.dates as mdates 

import plotly as py
import plotly.graph_objs as go

import ipywidgets as widgets

import pandas as pd
import datetime
import seaborn as sb

# %%
sb.set()

# %%
py.offline.init_notebook_mode(connected = True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ### Time Series Plot of Picroside III (Metabolite_id = 1288)

# %%
cnx = mysql.connector.connect(user='root', password='root',
                              host='127.0.0.1',
                              database='bioeco')

sql_query = pd.read_sql_query('''select bioanalysis_metabolite_price.date, bioanalysis_metabolite_price.price, bioanalysis_metabolite_price.amount, bioanalysis_metabolite_price.unity, provider.name as provider_name
                                 from bioanalysis_metabolite_price
                                 JOIN provider 
                                 on provider.id = bioanalysis_metabolite_price.provider_id
                                 where metabolite_id = 1288; ''', cnx, index_col = 'date', parse_dates=True)


df = pd.DataFrame(sql_query, columns=['price', 'amount', 'unity', 'provider_name'])
print(df)
# Out:
#                       price  amount unity               provider_name
# date
# 2017-09-29 18:30:34   553.0     5.0    mg                   ChemFaces
# 2017-09-29 18:30:34   228.0    20.0    mg                   ChemFaces
# 2017-09-29 18:30:34   262.5     1.0    mg  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   337.5     2.0    mg  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   412.5     3.0    mg  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   487.5     4.0    mg  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   562.5     5.0    mg  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   637.5     6.0    mg  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   712.5     7.0    mg  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   787.5     8.0    mg  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   862.5     9.0    mg  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   937.5    10.0    mg  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34  1000.0    11.0    mg  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34  1062.5    12.0    mg  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34  1125.0    13.0    mg  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34  1187.5    14.0    mg  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34  1250.0    15.0    mg  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34  1312.5    16.0    mg  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34  1375.0    17.0    mg  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34  1437.5    18.0    mg  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34  1500.0    19.0    mg  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34  1562.5    20.0    mg  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34  1612.5    21.0    mg  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34  1662.5    22.0    mg  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34  1712.5    23.0    mg  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34  1762.5    24.0    mg  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34  1812.5    25.0    mg  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34  1862.5    26.0    mg  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34  1912.5    27.0    mg  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34  1962.5    28.0    mg  AnalytiCon Discovery, GmbH
# ...                     ...     ...   ...                         ...
# 2019-05-05 21:07:41   890.1     9.0    mg  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41   967.5    10.0    mg  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41  1032.0    11.0    mg  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41  1096.5    12.0    mg  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41  1161.0    13.0    mg  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41  1225.5    14.0    mg  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41  1290.0    15.0    mg  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41  1354.5    16.0    mg  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41  1419.0    17.0    mg  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41  1483.5    18.0    mg  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41  1548.0    19.0    mg  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41  1612.5    20.0    mg  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41  1664.1    21.0    mg  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41  1715.7    22.0    mg  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41  1767.3    23.0    mg  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41  1818.9    24.0    mg  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41  1870.5    25.0    mg  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41  1922.1    26.0    mg  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41  1973.7    27.0    mg  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41  2025.3    28.0    mg  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41  2076.9    29.0    mg  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41  2128.5    30.0    mg  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41  3160.5    50.0    mg  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41  6321.0   100.0    mg  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41   553.0     5.0    mg                   ChemFaces
# 2019-05-05 21:07:41   228.0    20.0    mg                   ChemFaces
# 2019-05-05 21:07:41    63.0     2.0    mg                   TargetMol
# 2019-05-05 21:07:41   113.0     5.0    mg                   TargetMol
# 2019-05-05 21:07:41   467.0    20.0    mg                   Labseeker
# 2019-05-05 21:07:41  1833.0     1.0     g                   Labseeker
#
# [724 rows x 4 columns]

# %% [markdown]
# NaT is the equivalent of NaN for time (NaT = Not a Time)

# %%
df.unity.unique()
# Out:
# array(['mg', 'g'], dtype=object)

# %%
df = df.sort_index()

fig, ax = plt.subplots(figsize=(20, 15))
for k,g in df.groupby(['provider_name'])['price']:
    ax.plot_date(pd.to_datetime(g.index),g,'v-',label="{}, {}".format(*k))


#ax.xaxis.set_major_locator(mdates.MonthLocator(interval=3))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b\n%Y'))
ax.legend(loc='best')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.show()

# %%
# Converter mg em g!!
df.amount = np.where(df.unity == 'mg', df.amount/1000, df.amount)  # where True, yield x, otherwise yield y
df = df.replace({'mg':'g'})
print(df)
# Out:
#                       price  amount unity               provider_name
# date
# 2017-09-29 18:30:34   553.0   0.005     g                   ChemFaces
# 2017-09-29 18:30:34   228.0   0.020     g                   ChemFaces
# 2017-09-29 18:30:34   262.5   0.001     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   337.5   0.002     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   412.5   0.003     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   487.5   0.004     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   562.5   0.005     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   637.5   0.006     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   712.5   0.007     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   787.5   0.008     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   862.5   0.009     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   937.5   0.010     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34  1000.0   0.011     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34  1062.5   0.012     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34  1125.0   0.013     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34  1187.5   0.014     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34  1250.0   0.015     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34  1312.5   0.016     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34  1375.0   0.017     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34  1437.5   0.018     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34  1500.0   0.019     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34  1562.5   0.020     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34  1612.5   0.021     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34  1662.5   0.022     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34  1712.5   0.023     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34  1762.5   0.024     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34  1812.5   0.025     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34  1862.5   0.026     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34  1912.5   0.027     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34  1962.5   0.028     g  AnalytiCon Discovery, GmbH
# ...                     ...     ...   ...                         ...
# 2019-05-05 21:07:41   890.1   0.009     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41   967.5   0.010     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41  1032.0   0.011     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41  1096.5   0.012     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41  1161.0   0.013     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41  1225.5   0.014     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41  1290.0   0.015     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41  1354.5   0.016     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41  1419.0   0.017     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41  1483.5   0.018     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41  1548.0   0.019     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41  1612.5   0.020     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41  1664.1   0.021     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41  1715.7   0.022     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41  1767.3   0.023     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41  1818.9   0.024     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41  1870.5   0.025     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41  1922.1   0.026     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41  1973.7   0.027     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41  2025.3   0.028     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41  2076.9   0.029     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41  2128.5   0.030     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41  3160.5   0.050     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41  6321.0   0.100     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41   553.0   0.005     g                   ChemFaces
# 2019-05-05 21:07:41   228.0   0.020     g                   ChemFaces
# 2019-05-05 21:07:41    63.0   0.002     g                   TargetMol
# 2019-05-05 21:07:41   113.0   0.005     g                   TargetMol
# 2019-05-05 21:07:41   467.0   0.020     g                   Labseeker
# 2019-05-05 21:07:41  1833.0   1.000     g                   Labseeker
#
# [724 rows x 4 columns]

# %%
df.unity.unique()
# Out:
# array(['g'], dtype=object)

# %%
df.plot('amount')

# %%
#Converter tudo a 1g e preços respetivos
df.price = np.where(df.amount != 1, df.price/df.amount, df.price)  # where True, yield x, otherwise yield y
df.amount = np.where(df.amount != 1, 1, df.amount)
print(df)
# Out:
#                              price  amount unity               provider_name
# date
# 2017-09-29 18:30:34  110600.000000     1.0     g                   ChemFaces
# 2017-09-29 18:30:34   11400.000000     1.0     g                   ChemFaces
# 2017-09-29 18:30:34  262500.000000     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34  168750.000000     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34  137500.000000     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34  121875.000000     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34  112500.000000     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34  106250.000000     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34  101785.714286     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   98437.500000     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   95833.333333     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   93750.000000     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   90909.090909     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   88541.666667     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   86538.461538     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   84821.428571     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   83333.333333     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   82031.250000     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   80882.352941     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   79861.111111     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   78947.368421     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   78125.000000     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   76785.714286     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   75568.181818     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   74456.521739     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   73437.500000     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   72500.000000     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   71634.615385     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   70833.333333     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   70089.285714     1.0     g  AnalytiCon Discovery, GmbH
# ...                            ...     ...   ...                         ...
# 2019-05-05 21:07:41   98900.000000     1.0     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41   96750.000000     1.0     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41   93818.181818     1.0     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41   91375.000000     1.0     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41   89307.692308     1.0     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41   87535.714286     1.0     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41   86000.000000     1.0     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41   84656.250000     1.0     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41   83470.588235     1.0     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41   82416.666667     1.0     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41   81473.684211     1.0     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41   80625.000000     1.0     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41   79242.857143     1.0     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41   77986.363636     1.0     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41   76839.130435     1.0     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41   75787.500000     1.0     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41   74820.000000     1.0     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41   73926.923077     1.0     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41   73100.000000     1.0     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41   72332.142857     1.0     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41   71617.241379     1.0     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41   70950.000000     1.0     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41   63210.000000     1.0     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41   63210.000000     1.0     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41  110600.000000     1.0     g                   ChemFaces
# 2019-05-05 21:07:41   11400.000000     1.0     g                   ChemFaces
# 2019-05-05 21:07:41   31500.000000     1.0     g                   TargetMol
# 2019-05-05 21:07:41   22600.000000     1.0     g                   TargetMol
# 2019-05-05 21:07:41   23350.000000     1.0     g                   Labseeker
# 2019-05-05 21:07:41    1833.000000     1.0     g                   Labseeker
#
# [724 rows x 4 columns]

# %%
#See results grouped by provider_name
grouped_df = df.groupby('provider_name')

for key, item in grouped_df:
    print(grouped_df.get_group(key), "\n\n")
# Out:
#                              price  amount unity               provider_name
# date
# 2017-09-29 18:30:34  262500.000000     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34  168750.000000     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34  137500.000000     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34  121875.000000     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34  112500.000000     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34  106250.000000     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34  101785.714286     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   98437.500000     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   95833.333333     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   93750.000000     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   90909.090909     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   88541.666667     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   86538.461538     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   84821.428571     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   83333.333333     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   82031.250000     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   80882.352941     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   79861.111111     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   78947.368421     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   78125.000000     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   76785.714286     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   75568.181818     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   74456.521739     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   73437.500000     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   72500.000000     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   71634.615385     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   70833.333333     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   70089.285714     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   69396.551724     1.0     g  AnalytiCon Discovery, GmbH
# 2017-09-29 18:30:34   68750.000000     1.0     g  AnalytiCon Discovery, GmbH
# ...                            ...     ...   ...                         ...
# 2019-05-05 21:07:41  141900.000000     1.0     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41  125775.000000     1.0     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41  116100.000000     1.0     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41  109650.000000     1.0     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41  105042.857143     1.0     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41  101587.500000     1.0     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41   98900.000000     1.0     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41   96750.000000     1.0     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41   93818.181818     1.0     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41   91375.000000     1.0     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41   89307.692308     1.0     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41   87535.714286     1.0     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41   86000.000000     1.0     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41   84656.250000     1.0     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41   83470.588235     1.0     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41   82416.666667     1.0     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41   81473.684211     1.0     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41   80625.000000     1.0     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41   79242.857143     1.0     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41   77986.363636     1.0     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41   76839.130435     1.0     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41   75787.500000     1.0     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41   74820.000000     1.0     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41   73926.923077     1.0     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41   73100.000000     1.0     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41   72332.142857     1.0     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41   71617.241379     1.0     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41   70950.000000     1.0     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41   63210.000000     1.0     g  AnalytiCon Discovery, GmbH
# 2019-05-05 21:07:41   63210.000000     1.0     g  AnalytiCon Discovery, GmbH
#
# [608 rows x 4 columns]
#
#
#                      price  amount unity provider_name
# date
# 2018-01-07 19:56:11  400.0     1.0     g  Astatech Inc
# 2018-01-07 19:56:11  240.0     1.0     g  Astatech Inc
# 2018-02-09 16:13:21  400.0     1.0     g  Astatech Inc
# 2018-02-09 16:13:21  240.0     1.0     g  Astatech Inc
# 2018-02-09 16:13:24  400.0     1.0     g  Astatech Inc
# 2018-02-09 16:13:24  240.0     1.0     g  Astatech Inc
# 2018-03-09 18:30:58  400.0     1.0     g  Astatech Inc
# 2018-03-09 18:30:58  240.0     1.0     g  Astatech Inc
# 2018-04-09 20:06:05  400.0     1.0     g  Astatech Inc
# 2018-04-09 20:06:05  240.0     1.0     g  Astatech Inc
# 2018-04-09 20:06:07  400.0     1.0     g  Astatech Inc
# 2019-03-05 21:59:01   1833.0     1.0     g     Labseeker
# 2019-04-05 20:59:09  23350.0     1.0     g     Labseeker
# 2019-04-05 20:59:09   1833.0     1.0     g     Labseeker
# 2019-05-05 21:07:41  23350.0     1.0     g     Labseeker
# 2019-05-05 21:07:41   1833.0     1.0     g     Labseeker
#
#
#                        price  amount unity provider_name
# date
# 2019-02-05 21:58:50  31500.0     1.0     g     TargetMol
# 2019-02-05 21:58:50  22600.0     1.0     g     TargetMol
# 2019-03-05 21:59:01  31500.0     1.0     g     TargetMol
# 2019-03-05 21:59:01  22600.0     1.0     g     TargetMol
# 2019-04-05 20:59:09  31500.0     1.0     g     TargetMol
# 2019-04-05 20:59:09  22600.0     1.0     g     TargetMol
# 2019-05-05 21:07:41  31500.0     1.0     g     TargetMol
# 2019-05-05 21:07:41  22600.0     1.0     g     TargetMol
#
#
#                        price  amount unity            provider_name
# date
# 2018-05-10 00:47:17  1371.00     1.0     g  UORSY Chemspace partner
# 2018-05-10 00:47:17   113.72     1.0     g  UORSY Chemspace partner
# 2018-05-10 00:47:17   720.20     1.0     g  UORSY Chemspace partner
# 2018-05-10 00:47:17   452.70     1.0     g  UORSY Chemspace partner

# %%
#Create plot!!
df = df.sort_index()

fig, ax = plt.subplots(figsize=(20, 15))
for k,g in df.groupby(['provider_name'])['price']:
    ax.plot_date(pd.to_datetime(g.index),g,'v-',label="{}, {}".format(*k))


#ax.xaxis.set_major_locator(mdates.MonthLocator(interval=3))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b\n%Y'))
ax.legend(loc='best')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.show()

# %%
#Create plot with plotly

df = df.sort_index()


layout = go.Layout(
    title = 'Time Series Plot of Picroside III (1g)',
    yaxis = dict(
        title = 'price(USD)'
    ),
    xaxis = dict(
        title = 'date'
    )
)

prov_list = []
for key, item in grouped_df:
    prov_list.append(key)
    

d_x = {}
d_y = {}
for k,g in df.groupby(['provider_name'])['price']:
    x = pd.to_datetime(g.index)
    y = g.values
    if k not in d_x and k not in d_y:
        d_x[k] = x
        d_y[k] = y
    elif k in d_x and k in d_y:
        d_x[k].append(x)
        d_y[k].append(y)
    else: print('There is a provider lacking on the x or y dict.')
    


def update_plot(signals):#, freq):
   data = []
   for s in signals:
       trace1 = go.Scatter(
           x = d_x[s],
           y = d_y[s],
           mode = 'lines',
           name = 'provider {}'.format(s),
           line = dict(
               shape = 'spline' #smooth line
           )
       )
       data.append(trace1)
    
   fig = go.Figure(data = data, layout= layout)
   py.offline.iplot(fig)

    
signals = widgets.SelectMultiple(options = prov_list, description = 'Provider')
#freq = widgets.FloatSlider(min=1, max=20, value=1, description = 'Freq')
widgets.interactive(update_plot, signals = signals)#, freq = freq)
# Out:
# interactive(children=(SelectMultiple(description='Provider', options=('AnalytiCon Discovery, GmbH', 'Astatech …

# %% [markdown]
# Aqui é possível ver como o provider UORSY tem vários valores para o mesmo dia e mais nada. Provavelmente só se retirou valores deste dia para este provider mas em diferentes unidades e ao normalizar para 1g ficou como se vê estranho.
